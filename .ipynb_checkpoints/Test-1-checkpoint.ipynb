# %%
def problem1(example, rotational_value):
    #To Encode the sentence i translate the character values to ascii using the ord command
    #I then add the rv value (positive or negative) to the ascii number and translate it back to
    #a character code.  As I am looping through the individual characters I am rebuilding the string
    #using concatenation and I then return the Encoded sentence.
    def Encode(sentence, rv):
        translated = ""
        for x in sentence:
            translated += chr(ord(x)+rv)
        return translated

    #To Decode I do the exact same formula as the Encode except i subtract the rotational value
    #This decodes the sentence an I return it.
    def Decode(sentence, rv):
        translated = ""
        for x in sentence:
            translated += chr(ord(x)-rv)
        return translated
    encoded = Encode(example, rotational_value)
    decoded = Decode(encoded, rotational_value)
    print("Enter a Message to Encrypt:", example)
    print("The Encrypted Message is:",encoded)
    print("The Decrypted Message is:",decoded)
problem1("Hello World!",13)

# %%
import math
def flowercount(ls, flower_dict, H):
    for y in H:
        for x in ls:
            temp=y+"count"
            try:
                flower_dict[x[-1]][temp]+=1
            except:
                try:
                    flower_dict[x[-1]].update({temp:1})
                except:
                    flower_dict[x[-1]]={temp:1}
    return flower_dict
    
def flowersums(ls, flower_dict, H):
    z=-1
    for y in H:
        z+=1
        for x in ls:
            temp=y+"sum"
            try:
                flower_dict[x[-1]][temp]+=float(x[z])
            except:
                flower_dict[x[-1]].update({temp:float(x[z])})
    return flower_dict

def flowermins(ls, flower_dict, H):
    z=-1
    for y in H:
        z+=1
        for x in ls:
            temp=y+"min"
            try:
                if flower_dict[x[-1]][temp]>float(x[z]):
                    flower_dict[x[-1]][temp]=float(x[z])
            except:
                flower_dict[x[-1]].update({temp:float(x[z])})
    return flower_dict

def flowermax(ls, flower_dict, H):
    z=-1
    for y in H:
        z+=1
        for x in ls:
            temp=y+"max"
            try:
                if flower_dict[x[-1]][temp]>float(x[z]):
                    flower_dict[x[-1]][temp]=float(x[z])
            except:
                flower_dict[x[-1]].update({temp:float(x[z])})
    return flower_dict

def flowermean(ls, flower_dict, H):
    z=-1
    for y in H:
        z+=1
        for x in ls:
            temp=y+"mean"
            try:
                flower_dict[x[-1]][temp]=flower_dict[x[-1]][y+"sum"]/flower_dict[x[-1]][y+"count"]
            except:
                flower_dict[x[-1]].update({temp:flower_dict[x[-1]][y+"sum"]/flower_dict[x[-1]][y+"count"]})
    return flower_dict

def flowervar(ls, flower_dict, H):
    tempsum={}
    z=-1
    for y in H:
        z+=1
        for x in ls:
            temp=y+"var"
            try:
                tempsum[x[-1]]+=(float(x[z])-flower_dict[x[-1]][y+"mean"])**2
            except:
                tempsum[x[-1]]=0
            else:
                try:
                    flower_dict[x[-1]][temp]=tempsum[x[-1]]/flower_dict[x[-1]][y+"count"]
                except:
                    flower_dict[x[-1]].update({temp:tempsum[x[-1]]/flower_dict[x[-1]][y+"count"]})
    return flower_dict

def flowerstd(ls, flower_dict, H):
    z=-1
    for y in H:
        z+=1
        for x in ls:
            temp=y+"std"
            try:
                flower_dict[x[-1]][temp]=math.sqrt(flower_dict[x[-1]][y+"var"])
            except:
                flower_dict[x[-1]].update({temp:math.sqrt(flower_dict[x[-1]][y+"var"])})
    return flower_dict

filename="iris.txt"
fulllist=[]
flowers={}
fin=open(filename,'r')
Headers = fin.readline().split(",")
Headers=Headers[0:4]
for f in fin.readlines()[0:]:
    temp=f.split(",")
    temp[-1]=temp[-1].replace("Iris-","").strip("\n")
    temp[-1]=temp[-1][0].upper()+temp[-1][1:]
    fulllist.append(temp)
print(fulllist)
flowers = flowercount(fulllist, flowers, Headers)
flowers = flowersums(fulllist,flowers, Headers)
flowers = flowermins(fulllist,flowers, Headers)
flowers = flowermax(fulllist,flowers, Headers)
flowers = flowermean(fulllist,flowers, Headers)
flowers = flowervar(fulllist,flowers, Headers)
flowers = flowerstd(fulllist,flowers, Headers)
print(flowers)
# Out:
# [['5.1', '3.5', '1.4', '0.2', 'Setosa'], ['4.9', '3.0', '1.4', '0.2', 'Setosa'], ['4.7', '3.2', '1.3', '0.2', 'Setosa'], ['4.6', '3.1', '1.5', '0.2', 'Setosa'], ['5.0', '3.6', '1.4', '0.2', 'Setosa'], ['5.4', '3.9', '1.7', '0.4', 'Setosa'], ['4.6', '3.4', '1.4', '0.3', 'Setosa'], ['5.0', '3.4', '1.5', '0.2', 'Setosa'], ['4.4', '2.9', '1.4', '0.2', 'Setosa'], ['4.9', '3.1', '1.5', '0.1', 'Setosa'], ['5.4', '3.7', '1.5', '0.2', 'Setosa'], ['4.8', '3.4', '1.6', '0.2', 'Setosa'], ['4.8', '3.0', '1.4', '0.1', 'Setosa'], ['4.3', '3.0', '1.1', '0.1', 'Setosa'], ['5.8', '4.0', '1.2', '0.2', 'Setosa'], ['5.7', '4.4', '1.5', '0.4', 'Setosa'], ['5.4', '3.9', '1.3', '0.4', 'Setosa'], ['5.1', '3.5', '1.4', '0.3', 'Setosa'], ['5.7', '3.8', '1.7', '0.3', 'Setosa'], ['5.1', '3.8', '1.5', '0.3', 'Setosa'], ['5.4', '3.4', '1.7', '0.2', 'Setosa'], ['5.1', '3.7', '1.5', '0.4', 'Setosa'], ['4.6', '3.6', '1.0', '0.2', 'Setosa'], ['5.1', '3.3', '1.7', '0.5', 'Setosa'], ['4.8', '3.4', '1.9', '0.2', 'Setosa'], ['5.0', '3.0', '1.6', '0.2', 'Setosa'], ['5.0', '3.4', '1.6', '0.4', 'Setosa'], ['5.2', '3.5', '1.5', '0.2', 'Setosa'], ['5.2', '3.4', '1.4', '0.2', 'Setosa'], ['4.7', '3.2', '1.6', '0.2', 'Setosa'], ['4.8', '3.1', '1.6', '0.2', 'Setosa'], ['5.4', '3.4', '1.5', '0.4', 'Setosa'], ['5.2', '4.1', '1.5', '0.1', 'Setosa'], ['5.5', '4.2', '1.4', '0.2', 'Setosa'], ['4.9', '3.1', '1.5', '0.1', 'Setosa'], ['5.0', '3.2', '1.2', '0.2', 'Setosa'], ['5.5', '3.5', '1.3', '0.2', 'Setosa'], ['4.9', '3.1', '1.5', '0.1', 'Setosa'], ['4.4', '3.0', '1.3', '0.2', 'Setosa'], ['5.1', '3.4', '1.5', '0.2', 'Setosa'], ['5.0', '3.5', '1.3', '0.3', 'Setosa'], ['4.5', '2.3', '1.3', '0.3', 'Setosa'], ['4.4', '3.2', '1.3', '0.2', 'Setosa'], ['5.0', '3.5', '1.6', '0.6', 'Setosa'], ['5.1', '3.8', '1.9', '0.4', 'Setosa'], ['4.8', '3.0', '1.4', '0.3', 'Setosa'], ['5.1', '3.8', '1.6', '0.2', 'Setosa'], ['4.6', '3.2', '1.4', '0.2', 'Setosa'], ['5.3', '3.7', '1.5', '0.2', 'Setosa'], ['5.0', '3.3', '1.4', '0.2', 'Setosa'], ['7.0', '3.2', '4.7', '1.4', 'Versicolor'], ['6.4', '3.2', '4.5', '1.5', 'Versicolor'], ['6.9', '3.1', '4.9', '1.5', 'Versicolor'], ['5.5', '2.3', '4.0', '1.3', 'Versicolor'], ['6.5', '2.8', '4.6', '1.5', 'Versicolor'], ['5.7', '2.8', '4.5', '1.3', 'Versicolor'], ['6.3', '3.3', '4.7', '1.6', 'Versicolor'], ['4.9', '2.4', '3.3', '1.0', 'Versicolor'], ['6.6', '2.9', '4.6', '1.3', 'Versicolor'], ['5.2', '2.7', '3.9', '1.4', 'Versicolor'], ['5.0', '2.0', '3.5', '1.0', 'Versicolor'], ['5.9', '3.0', '4.2', '1.5', 'Versicolor'], ['6.0', '2.2', '4.0', '1.0', 'Versicolor'], ['6.1', '2.9', '4.7', '1.4', 'Versicolor'], ['5.6', '2.9', '3.6', '1.3', 'Versicolor'], ['6.7', '3.1', '4.4', '1.4', 'Versicolor'], ['5.6', '3.0', '4.5', '1.5', 'Versicolor'], ['5.8', '2.7', '4.1', '1.0', 'Versicolor'], ['6.2', '2.2', '4.5', '1.5', 'Versicolor'], ['5.6', '2.5', '3.9', '1.1', 'Versicolor'], ['5.9', '3.2', '4.8', '1.8', 'Versicolor'], ['6.1', '2.8', '4.0', '1.3', 'Versicolor'], ['6.3', '2.5', '4.9', '1.5', 'Versicolor'], ['6.1', '2.8', '4.7', '1.2', 'Versicolor'], ['6.4', '2.9', '4.3', '1.3', 'Versicolor'], ['6.6', '3.0', '4.4', '1.4', 'Versicolor'], ['6.8', '2.8', '4.8', '1.4', 'Versicolor'], ['6.7', '3.0', '5.0', '1.7', 'Versicolor'], ['6.0', '2.9', '4.5', '1.5', 'Versicolor'], ['5.7', '2.6', '3.5', '1.0', 'Versicolor'], ['5.5', '2.4', '3.8', '1.1', 'Versicolor'], ['5.5', '2.4', '3.7', '1.0', 'Versicolor'], ['5.8', '2.7', '3.9', '1.2', 'Versicolor'], ['6.0', '2.7', '5.1', '1.6', 'Versicolor'], ['5.4', '3.0', '4.5', '1.5', 'Versicolor'], ['6.0', '3.4', '4.5', '1.6', 'Versicolor'], ['6.7', '3.1', '4.7', '1.5', 'Versicolor'], ['6.3', '2.3', '4.4', '1.3', 'Versicolor'], ['5.6', '3.0', '4.1', '1.3', 'Versicolor'], ['5.5', '2.5', '4.0', '1.3', 'Versicolor'], ['5.5', '2.6', '4.4', '1.2', 'Versicolor'], ['6.1', '3.0', '4.6', '1.4', 'Versicolor'], ['5.8', '2.6', '4.0', '1.2', 'Versicolor'], ['5.0', '2.3', '3.3', '1.0', 'Versicolor'], ['5.6', '2.7', '4.2', '1.3', 'Versicolor'], ['5.7', '3.0', '4.2 ...
# 0.011235999999999784
# 0.10487199999999927
# 0.26970799999999906
# 0.26974399999999904
# 0.4249799999999998
# 0.5898159999999996
# 0.5898519999999996
# 0.9570879999999984
# 0.9683239999999982
# 1.123559999999999
# 1.1659959999999987
# 1.2084319999999984
# 1.7068679999999978
# 2.3373039999999987
# 2.81894
# 2.974176000000001
# 2.983012000000001
# 3.464648000000002
# 28.13799600000001
# 28.244272000000013
# 28.274548000000014
# 28.325624000000012
# 28.55030000000001
# 28.55097600000001
# 28.58125200000001
# 28.59712800000001
# 28.597804000000007
# 28.60328000000001
# 28.60875600000001
# 28.74863200000001
# 28.778908000000012
# 28.885184000000013
# 28.93626000000001
# 29.042536000000013
# 29.05841200000001
# 29.13348800000001
# 29.16376400000001
# 29.23884000000001
# 29.26911600000001
# 29.26979200000001
# 29.270468000000008
# 29.271144000000007
# 29.287020000000005
# 29.292496000000007
# 29.308372000000006
# 29.414648000000007
# 29.415324000000005
# 29.431200000000004
# 29.431876000000003
# 29.432552
# 29.483628
# 29.484303999999998
# 39.975532
# 39.991408
# 39.996884
# 40.04796
# 40.078236000000004
# 40.083712000000006
# 40.18998800000001
# 40.24106400000001
# 40.29214000000001
# 40.51681600000001
# 40.51749200000001
# 40.53336800000001
# 40.53884400000001
# 40.53952000000001
# 40.67939600000001
# 40.754472000000014
# 40.805548000000016
# 40.83582400000002
# 40.91090000000002
# 41.18757600000002
# 41.262652000000024
# 41.26332800000002
# 41.26400400000002
# 41.31508000000002
# 41.320556000000025
# 41.37163200000003
# 41.42270800000003
# 41.47378400000003
# 41.47926000000003
# 41.66073600000003
# 41.67661200000003
# 41.677288000000026
# 41.707564000000026
# 41.98424000000003
# 42.376116000000025
# 42.45119200000003
# 42.59106800000003
# 42.64214400000003
# 42.69322000000003
# 42.698696000000034
# 42.838572000000035
# 42.91364800000004
# 42.929524000000036
# 43.00460000000004
# 43.22927600000004
# 43.304352000000044
# 43.32022800000004
# 43.32090400000004
# 43.395980000000044
# 43.447056000000046
# {'Virginica': {'SepalLengthvar': 0.39459711999999997, 'SepalLengthsum': 329.3999999999999, 'PetalLengthsum': 277.59999999999997, 'SepalLengthmean': 6.587999999999998, 'PetalWidthmean': 2.026, 'SepalLengthmax': 4.9, 'PetalWidthvar': 0.8689411200000009, 'SepalLengthmin': 4.9, 'SepalWidthmin': 2.2, 'SepalLengthcount': 50, 'SepalWidthcount': 50, 'SepalWidthvar': 0.49652111999999987, 'PetalLengthcount': 50, 'PetalWidthmax': 1.4, 'PetalLengthstd': 0.8916373253739437, 'PetalLengthmean': 5.552, 'PetalLengthmin': 4.5, 'PetalWidthstd': 0.932170113230413, 'PetalWidthsum': 101.29999999999998, 'PetalLengthmax': 4.5, 'PetalLengthvar': 0.79501712, 'SepalWidthsum': 148.7, 'PetalWidthmin': 1.4, 'SepalWidthstd': 0.704642547679318, 'SepalLengthstd': 0.6281696586114296, 'SepalWidthmax': 2.2, 'PetalWidthcount': 50, 'SepalWidthmean': 2.9739999999999998}, 'Versicolor': {'SepalLengthvar': 0.2384620800000001, 'SepalLengthsum': 296.8, 'PetalLengthsum': 212.99999999999997, 'SepalLengthmean': 5.936, 'PetalWidthmean': 1.3259999999999998, 'SepalLengthmax': 4.9, 'PetalWidthvar': 0.58968608, 'SepalLengthmin': 4.9, 'SepalWidthmin': 2.0, 'SepalLengthcount': 50, 'SepalWidthcount': 50, 'SepalWidthvar': 0.33496208000000005, 'PetalLengthcount': 50, 'PetalWidthmax': 1.0, 'PetalLengthstd': 0.7425375950078219, 'PetalLengthmean': 4.26, 'PetalLengthmin': 3.0, 'PetalWidthstd': 0.7679102030836679, 'PetalWidthsum': 66.3, 'PetalLengthmax': 3.0, 'PetalLengthvar': 0.5513620800000001, 'SepalWidthsum': 138.50000000000003, 'PetalWidthmin': 1.0, 'SepalWidthstd': 0.5787590863217614, 'SepalLengthstd': 0.48832579288831357, 'SepalWidthmax': 2.0, 'PetalWidthcount': 50, 'SepalWidthmean': 2.7700000000000005}, 'Setosa': {'SepalLengthvar': 0.12158727999999991, 'SepalLengthsum': 250.29999999999998, 'PetalLengthsum': 73.2, 'SepalLengthmean': 5.005999999999999, 'PetalWidthmean': 0.2439999999999999, 'SepalLengthmax': 4.3, 'PetalWidthvar': 0.30463128000000056, 'SepalLengthmin': 4.3, 'SepalWidthmin': 2.3, 'SepalLengthcount': 50, 'SepalWidthcount': 50, 'SepalWidthvar': 0.2638632800000001, 'PetalLengthcount': 50, 'PetalWidthmax': 0.1, 'PetalLengthstd': 0.5416338984960233, 'PetalLengthmean': 1.464, 'PetalLengthmin': 1.0, 'PetalWidthstd': 0.551934126504242, 'PetalWidthsum': 12.199999999999996, 'PetalLengthmax': 1.0, 'PetalLengthvar': 0.2933672800000004, 'SepalWidthsum': 170.90000000000003, 'PetalWidthmin': 0.1, 'SepalWidthstd': 0.5136762404472297, 'SepalLengthstd': 0.348693676455424, 'SepalWidthmax': 2.3, 'PetalWidthcount': 50, 'SepalWidthmean': 3.4180000000000006}}

# %%
# I imported the bible then read in the words into 2 dictionaries, 1 for word frequency and 1 for word length
# I used these to pull max and mins and other statistical values.

import statistics as st
import numpy as np
filename="bible.txt"
wordcounts={}
wordlengths={}
ls = []
fin=open(filename,'r')
for f in fin.readlines():
    ls.append(f.split())
for x in ls:
    for i in x:
        tempi=""
        i=i.lower().strip()
        for j in i:
            if j.isalpha():
                tempi += j
        i=tempi
        try:
            wordcounts[i] += 1
            wordlengths[i] = len(i)
        except:
            wordcounts[i] = 1
loop = 0
for y in reversed(sorted(wordcounts, key=wordcounts.get)):
    try:
        if loop>=10:
            raise
    except:
        break
    else:
        word = y+":"
        print(word.ljust(10),wordcounts[y])
        loop+=1
        
loop = 0
for y in reversed(sorted(wordlengths, key=wordlengths.get)):
    try:
        if loop>=10:
            raise
    except:
        break
    else:
        word = y+":"
        print(word.ljust(10),wordlengths[y])
        loop+=1
        
templen=0
templist =[]
for y in reversed(sorted(wordlengths, key=wordlengths.get)):
    templen += wordlengths[y]
    templist.append(wordlengths[y])
print("The mean word length is:", templen/len(wordlengths))
print("The Standard Deviation is: ", np.std(templist, axis=0))
# Out:
# the:       64203
# and:       51764
# of:        34789
# :          31150
# to:        13660
# that:      12927
# in:        12725
# he:        10421
# shall:     9840
# unto:      8997
# httpwwwgutenbergorg: 19
# mahershalalhashbaz: 18
# chushanrishathaim: 17
# lovingkindnesses: 16
# kibrothhattaavah: 16
# threshingfloors: 15
# righteousnesses: 15
# almondiblathaim: 15
# notwithstanding: 15
# tilgathpilneser: 15
# The mean word length is: 6.896532248955157
# The Standard Deviation is:  2.20330157827
