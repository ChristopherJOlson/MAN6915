# %% [markdown]
# # Olson - Assignment 3
# ## Part 1 - Read in the Data Set
# - using the Pandas native csv reading I read the iris.txt into a DataFrame df
# - This setup allows us to use df as a pandas datafram to use throughout the other sections

# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline
df = pd.read_csv("iris.txt")

# %% [markdown]
# ## Part 2 - Explore the Data
# - Using the native dataframe head and tail functions I printed the first and last 5 rows of the dataframe
# - The describe() pandas function prints summary statistics on the datafram without separating the groups
# - I then used the plot functions to create box, line, and histogram plots
#
# ### Interpret Results
# - According to the results there is not much variance in the Sepal Width of the flowers
# - There is some variance amonth Petal Width and Sepal Length
# - There is a lot of Variance in Petal Length across the data
# - Sepal Width on most flowers seems to be between 2.5 and 3.25

# %%
print(df.head())
print(df.tail())
print(df.describe())
df.plot.box()
df.plot.line()
df.plot.hist()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# ...

# %% [markdown]
# ## Part 3 - Explore Grouped Data
# - I created a grouped datafram dfg to run analysis against
# - I then printed the summary statistcs using the describe function on the groped datafram
# - I then created a box plot against each grouped sectio of data
# - I then used the scatter_matrix function to create a scatter plot matrix on the original dataframe, I used a histogram as the diagonal chart
#
# ### Interpret Results
# - Setosa Flowers have the smallest petals and Sepals
# - Versicolor flowers are medium sized Petals and Sepals
# - Virginica flowers ae the largest Petals and similar Sepals to the Versicolor
#
# - There is a significant positive correlation betwen Peta Length and Petal Width
# - There is a positive correlation between most attibutes, some beng more prominent than others

# %%
dfg = df.groupby("Species")
print(dfg.describe())
dfg.plot.box()
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='hist')
# Out:
#                        PetalLength  PetalWidth  SepalLength  SepalWidth
# Species
# Iris-setosa     count    50.000000   50.000000    50.000000   50.000000
#                 mean      1.464000    0.244000     5.006000    3.418000
#                 std       0.173511    0.107210     0.352490    0.381024
#                 min       1.000000    0.100000     4.300000    2.300000
#                 25%       1.400000    0.200000     4.800000    3.125000
#                 50%       1.500000    0.200000     5.000000    3.400000
#                 75%       1.575000    0.300000     5.200000    3.675000
#                 max       1.900000    0.600000     5.800000    4.400000
# Iris-versicolor count    50.000000   50.000000    50.000000   50.000000
#                 mean      4.260000    1.326000     5.936000    2.770000
#                 std       0.469911    0.197753     0.516171    0.313798
#                 min       3.000000    1.000000     4.900000    2.000000
# ...

# %% [markdown]
# ## Part 4 - Analysis Question
# - Given an iris flower's petal length, petal width, sepal length, and sepal width, what variable(s) should we look at if we wanted to predict the species of the flower?
#     - According to the graphs (especially the box plots) I can see that there is very little overlap in Petal Length and Petal Width between species so I would use that information to predict which species the flower is.  Even more so would be the combination of the 2.  For example if petal length was between 1 and 1.9 and Petal width was between .1 and .6 I would predict the flower to be Setosa.  The other flowers would be done similarly.
